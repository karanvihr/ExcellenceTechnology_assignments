# %%
# 4. Logical Operators

num1 = 100 
num2 = 200
# Use AND operator
if num1>500 and num2>500 :
    print("both the numbers are greater than 500")
# Use OR operator 
if num1<500 or num2<500 :
    print("either of the number is  less than 500")
# Use NOT operator
if not num1>500 and not num2>500 :
    print("both the numbers are smaller than 500")
# Out:
# either of the number is  less than 500
# both the numbers are smaller than 500

# %%
#  validate login 
set_user = input("enter username to set username")
set_pass = (input("enter password to set password"))
import random
otp = random.randint(1000,9999)
print("your login OTP: ",otp)

ent_otp = int(input("An OTP has sent to you"))

if ent_otp == otp:
    print("your username and password has  been confirmed.")

login_usr = input("enter username")
login_pass = input("enter password")

if login_usr == set_user and login_pass == set_pass:
    print("you have logged in successfully to your account.")
elif login_pass != set_pass and login_usr == set_user:
    print("Incorrect password!")
elif set_user != login_usr :
    print("user name  doesn't exist. ")
# Out:
# your login OTP:  1749
# your username and password has  been confirmed.
# you have logged in successfully to your account.

# %%
# ATM withdrawl conditions 

set_user = input("enter username to set username")
set_pass = (input("enter password to set password"))
import random
otp = random.randint(1000,9999)
print("your login OTP: ",otp)

ent_otp = int(input("An OTP has sent to you"))

if ent_otp == otp:
    print("your username and password has  been confirmed.")

login_usr = input("enter username")
login_pass = input("enter password")

if login_usr == set_user and login_pass == set_pass:
    print("you have logged in successfully to your account.")
elif login_pass != set_pass and login_usr == set_user:
    print("Incorrect password!")
elif set_user != login_usr :
    print("user name  doesn't exist. ") 

bal = 10000
print("your account Balance is : ",bal)  
withdraw  = int(input("to withdraw enter amount"))

if bal>withdraw:
    bal -=withdraw
    print("amount: ",withdraw,"has been withdrawn\n available balance: ",bal)
if bal<withdraw:
    print("Insufficient Balance")
# Out:
# your login OTP:  1833
# your username and password has  been confirmed.
# you have logged in successfully to your account.
# your account Balance is :  10000
# amount:  1200 has been withdrawn
#  available balance:  8800

# %%
#  Scholarship eligibility
score = int(input("enter your 12th score "))
age = int(input("enter your age"))
nationality = input("enter your nationality")

if score >=90 and age <=25 and nationality =="indian":
    print("you are eligible for scholarship")
else :
    print("you are not eligible for scholarship")
# Out:
# you are eligible for scholarship

# %%
# Ticket booking validation
# initialized seat availabilty ,payment and authentication ,age 

seat_avail = True
payment_done = True
authen_done = True
age = 23

if age>=18 and payment_done and authen_done :
    print("you ticket has been confirmed")
else:
    print("you are not eligible")

# %%
# loan approval
income = int(input("enter your monthly income"))
loan_taken = (input("enter 'y' if already has a loan going on or 'n' if has no current loan pending "))
loan_amount = int(input("enter amount to be loaned"))

loan_taken_bool = True
if loan_taken == 'n':
    loan_taken_bool = False
if income*12>loan_amount and loan_taken_bool != True :
    print("you are eligible for loan.")
else:
    print("you not eligible for loan.")
# Out:
# you not eligible for loan.

# %%
# Flight boarding checker
# luguage weight , payment , passport_valid 

luguage_underweight  = True
payment_done = True
passport_valid = True

if luguage_underweight and payment_done and passport_valid:
    print("you are eligible for boarding to flight")
else:
    print("not eligible")

# %%
# Strong password validation

# import re to check special characters in the password
import re
def has_special_char(text):
 pattern = re.compile(r'[^a-zA-Z0-9\s]')
 return bool(pattern.search(text))

def contains_int(text):
 return any(char.isdigit() for char in text)

def contains_upper(text):
 return any(char.isupper() for char in text)


while True:
 pas = input("enter a strong password")
 if(not has_special_char(pas) or not contains_int(pas) or not contains_upper(pas)):
  print("your password must contain a special character, a numeric value and a uppercase letter")
  continue
 if(has_special_char(pas) and contains_int(pas) and contains_upper(pas)):
  print("your password has been set successfully",pas)
  break 
















# while True:
#     if(int(len(pas))<8):
#      pas = input("your password must be atleast 8-digit character")
#     elif( not spec_char):
#      pas = input("your password must contain a special character")
#      spec_char(pas)
#     elif( not contains_num):
#      pas = input("your password must contain a number")
#     elif( not contains_up):
#      pas = input("your password must contain an upper case letter") 
#     elif (int(len(pas))>=8 and contains_num and contains_up and spec_char):
#      print("your password has been set successfully.")
#      break
# Out:
# your password must contain a special character, a numeric value and a uppercase letter
# your password must contain a special character, a numeric value and a uppercase letter
# your password has been set successfully Karan@2veer
